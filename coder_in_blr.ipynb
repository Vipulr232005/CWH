# %%
with open ("final_data.txt",encoding='utf-8')as f:
    data=f.read()

# %%
chunks=data.split("\n\n")

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')

    if len(sep_chunk) < 6:
        return None

    username = sep_chunk[0]
    no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",","" ))
    no_of_followers = float(sep_chunk[2].split("followers")[0].replace("K","") .replace("M","").replace(",","" ))
    if ("K" in sep_chunk[2]):
        no_of_followers=int(no_of_followers*1000)
    elif ("M" in sep_chunk[2]):
        no_of_followers=int(no_of_followers*1000000)
    else:
        no_of_followers=int(no_of_followers)
        


    no_of_following = float(sep_chunk[3].split("following")[0].replace("K","") .replace("M","").replace(",","" ))
    if ("K" in sep_chunk[3]):
        no_of_following=int(no_of_following*1000)
    elif ("M" in sep_chunk[3]):
        no_of_following=int(no_of_following*1000000)
    else:
        no_of_following=int(no_of_following)

    
    name = sep_chunk[4]
    type_of_page = sep_chunk[5]
    bio = "\n".join(sep_chunk[6:])

    return {
        "username": username,
        "no_of_posts": no_of_posts,
        "no_of_followers": no_of_followers,
        "no_of_following": no_of_following,
        "name": name,
        "type_of_page": type_of_page,
        "bio": bio
    }

# %%
all_chunks = []

for chunk in chunks:
    print(f"the chunk is :{chunk}")
    parsed_chunk = parse_chunk(chunk)

    if parsed_chunk is not None:
        all_chunks.append(parsed_chunk)
# Out:
# the chunk is :techie_koramangala
# 420 posts
# 9,800 followers
# 310 following
# Arjun M.
# Software Engineer
# 💻 Full-stack @ SaaS startup
# ☕ Working from cafes in Koramangala
# github.com/arjunmakes
# the chunk is :blrcoder_girl
# 150 posts
# 6,300 followers
# 120 following
# Riya Codes
# Tech Creator
# 👩‍💻 Python | ML | Roadmaps
# 🎥 Coding Reels + Daily Motivation
# linktr.ee/riyacodes
# the chunk is :hsr_startup_stories
# 980 posts
# 22.4K followers
# 95 following
# Startup Stories HSR
# Media
# 🚀 Interviews with Bangalore founders
# 🎙️ Weekly startup breakdowns
# hsrstartupstories.com
# the chunk is :cloud_dev_blr
# 210 posts
# 4,500 followers
# 60 following
# Naveen DevOps
# Engineer
# ☁️ AWS | Docker | K8s
# 📍 Sarjapur
# github.com/naveencloud
# the chunk is :koramangala_coffee_lover
# 300 posts
# 7,900 followers
# 180 following
# Sana B.
# Cafe Explorer
# ☕ Reviewing Bangalore’s hidden coffee spots
# 📍 Koramangala
# youtube.com/@sanacafehunter
# ...

# %%
import json

# %%
s=json.dumps(all_chunks,indent=4)
with open("blr_coder.json","w")as f:
    f.write(s)

# %%
max=0
for chunk in all_chunks:
    if (max<chunk['no_of_posts']):
        max=chunk['no_of_posts']
        chunk_with_max_post=chunk
print(chunk_with_max_post['username'])
# Out:
# startuphub_blr

# %%
max=0
for chunk in all_chunks:
    if (max<chunk['no_of_followers']):
        max=chunk['no_of_followers']
        chunk_with_max_followers=chunk
print(chunk_with_max_followers['username'])
# Out:
# _anujsinghal

# %%
max=0
for chunk in all_chunks:
    if (max<chunk['no_of_following']):
        max=chunk['no_of_following']
        chunk_with_max_following=chunk
print(chunk_with_max_following['username'])
# Out:
# bangalore_tech_bro

# %%
categories=set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"There are {len(categories)} catagories")
# Out:
# There are 34 catagories
